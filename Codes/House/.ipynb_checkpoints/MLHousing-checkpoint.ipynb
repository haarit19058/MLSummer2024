# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
data = pd.read_csv("Housing.csv")
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
prices  = np.array(data['price']/1000000)
area = np.array(data['area']/1000)
bedrooms = np.array(data['bedrooms'])

# %%
w = 0
b = 0

def gradientDescent(w,b,alp,x,y):
    m = len(x)
    
    dj_dw = (1/m)*np.sum(x*(w*x+b-y))
    dj_db = (1/m)*np.sum((w*x+b-y))

    w = w - alp * dj_dw
    b = b - alp * dj_db

    cf = (1/(2*m))*np.sum((w * x + b - y)**2)
    
    return cf,w,b

cfValues = []
w_values = []
b_values = []
for i in range(10000):
    cf,w,b = gradientDescent(w,b,0.02,area,prices)
    cfValues.append(cf)
    w_values.append(w)
    b_values.append(b)

print(w,b)
plt.plot(np.arange(10000),cfValues)
plt.show()
plt.plot(w_values,cfValues)
plt.show()
plt.plot(b_values,cfValues)
plt.show()
# Out:
# 0.4619748942728508 2.387308482396024

# %%
plt.scatter(area,prices)
# b= 8
# w = 0.03
pr = w * area + b
plt.scatter(area,pr)


plt.show()

# %%
prices  = np.array(data['price'][200:210]/10000000)
area = np.array(data['area'][200:210]/1000)
bedrooms = np.array(data['bedrooms'])

# print(b)

predicted = w*area+b

# print(area,predicted)
plt.scatter(area,prices)
plt.scatter(area,predicted)
plt.show()

# %%
# Assuming you have defined prices and area
m = prices.shape[0]
x = area
y = prices

# Define the range for w and b
w = np.arange(-100, 100)
b = np.arange(-100, 100)
w_, b_ = np.meshgrid(w, b)

# Initialize the cost array
cost = np.zeros(w_.shape)

# Calculate cost for each combination of w and b
for i in range(w_.shape[0]):
    for j in range(w_.shape[1]):
        cost[i][j] = (1/(2*m)) * np.sum((w_[i][j]*x + b_[i][j] - y)**2) 

# Create the 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(w_, b_, cost, cmap="viridis")
ax.set_title("Cost Function")
ax.set_xlabel("w")
ax.set_ylabel("b")
ax.set_zlabel("Cost")

# Show the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Housing.csv")
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
m=100
n=110
prices  = np.array((data['price'][m:n]-data['price'][m:n].mean())/data['price'][m:n].std())
area = np.array((data['area'][m:n]-data["area"][m:n].mean())/data['area'][m:n].std())

# %%
w = np.arange(-100,100)
b = np.arange(-100,100)

x = area
y = prices
m = x.shape[0]

w_ , b_ = np.meshgrid(w,b)
cf = np.zeros(w_.shape)

for i in range(w.shape[0]):
    for j in range(w.shape[0]):
        cf[i][j] = (1/(2*m)) * np.sum((w_[i][j]*x+b_[i][j]-y)**2)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(w_, b_, cf, cmap="viridis")
ax.set_title("Cost Function")
ax.set_xlabel("w")
ax.set_ylabel("b")
ax.set_zlabel("Cost")

# Show the plot
plt.show()

# %%
w = 0
b = 0

def gradientDescent(w,b,alp,x,y):
    m = len(x)
    
    dj_dw = (1/m)*np.sum(x*(w*x+b-y))
    dj_db = (1/m)*np.sum((w*x+b-y))

    w = w - alp * dj_dw
    b = b - alp * dj_db

    cf = (1/(2*m))*np.sum((w * x + b - y)**2)
    
    return cf,w,b

cfValues = []
w_values = []
b_values = []
for i in range(10000):
    cf,w,b = gradientDescent(w,b,0.02,area,prices)
    cfValues.append(cf)
    w_values.append(w)
    b_values.append(b)

print(w,b)
plt.plot(np.arange(10000),cfValues)
plt.show()
plt.plot(w_values,cfValues)
plt.show()
plt.plot(b_values,cfValues)
plt.show()
# Out:
# 0.23409398123650219 1.376676550535195e-17

# %%
# plt.scatter(prices,area)
plt.scatter(area,prices)
# b= 8
# w = 0.03
pr = w * area + b
plt.scatter(area,pr)


plt.show()
plt.show()

# %%
n = 100
priceForTest = data["price"][n]
areaForTest = data["area"][n]

predictedPrice = w * areaForTest + b
print(predictedPrice,priceForTest)
# Out:
# 1545.0202761609144 6230000
